# %% [markdown]
# # YOLOv5 installation

# %% [markdown]
# ## Cloning Repositories

# %%
# !nvidia-smi
# Out:
# Tue Jun 27 11:42:05 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.42.01    Driver Version: 470.42.01    CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  On   | 00000000:03:00.0  On |                  N/A |
# |  0%   51C    P8    34W / 320W |    480MiB / 10010MiB |     31%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A       937      G   ...RendererForSitePerProcess      127MiB |
# |    0   N/A  N/A      2052      G   /usr/lib/xorg/Xorg                 18MiB |
# |    0   N/A  N/A      2513      G   /usr/bin/gnome-shell               71MiB |
# |    0   N/A  N/A      4574      G   /usr/lib/xorg/Xorg                134MiB |
# |    0   N/A  N/A      4705      G   /usr/bin/gnome-shell               51MiB |
# |    0   N/A  N/A      9555      G   ...139349646870319049,262144       70MiB |
# +-----------------------------------------------------------------------------+

# %%
# !git clone https://github.com/ultralytics/yolov5.git

# %%
# %cd ./yolov5
# Out:
# /home/aiml-3080/Downloads/MJ/yolo/yolov5

# %%
# !git clone https://github.com/nwojke/deep_sort.git

# %% [markdown]
# ## Installing Requirements

# %%
# !pip install -r requirements.txt
# Out:
# Collecting matplotlib>=3.2.2 (from -r requirements.txt (line 4))
#   Using cached matplotlib-3.5.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
# Collecting numpy>=1.18.5 (from -r requirements.txt (line 5))
#   Using cached numpy-1.21.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
# Collecting opencv-python>=4.1.1 (from -r requirements.txt (line 6))
#   Using cached opencv_python-4.7.0.72-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (61.8 MB)
# Requirement already satisfied: Pillow>=7.1.2 in /home/aiml-3080/.local/lib/python3.7/site-packages (from -r requirements.txt (line 7)) (8.2.0)
# Requirement already satisfied: PyYAML>=5.3.1 in /home/aiml-3080/.local/lib/python3.7/site-packages (from -r requirements.txt (line 8)) (6.0)
# Collecting requests>=2.23.0 (from -r requirements.txt (line 9))
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Collecting scipy>=1.4.1 (from -r requirements.txt (line 10))
#   Using cached scipy-1.7.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (38.1 MB)
# Collecting torch>=1.7.0 (from -r requirements.txt (line 11))
#   Using cached torch-1.13.1-cp37-cp37m-manylinux1_x86_64.whl (887.5 MB)
# Collecting torchvision>=0.8.1 (from -r requirements.txt (line 12))
#   Using cached torchvision-0.14.1-cp37-cp37m-manylinux1_x86_64.whl (24.2 MB)
# Collecting tqdm>=4.41.0 (from -r requirements.txt (line 13))
#   Using cached tqdm-4.65.0-py3-none-any.whl (77 kB)
# Collecting tensorboard>=2.4.1 (from -r requirements.txt (line 16))
#   Using cached tensorboard-2.11.2-py3-none-any.whl (6.0 MB)
# Collecting pandas>=1.1.4 (from -r requirements.txt (line 20))
#   Using cached pandas-1.3.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
# Requirement already satisfied: seaborn>=0.11.0 in /home/aiml-3080/.local/lib/python3.7/site-packages (from -r requirements.txt (line 21)) (0.11.2)
# Collecting thop (from -r requirements.txt (line 37))
#   Using cached thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.2.2->-r requirements.txt (line 4))
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.2.2->-r requirements.txt (line 4))
#   Using cached fonttools-4.38.0-py3-none-any.whl (965 kB)
# Collecting kiwisolver>=1.0.1 (from matplotlib>=3.2.2->-r requirements.txt (line 4))
#   Using cached kiwisolver-1.4.4-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.1 MB)
# Requirement already satisfied: packaging>=20.0 in /home/aiml-3080/.local/lib/python3.7/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (23.1)
# Collecting pyparsing>=2.2.1 (from matplotlib>=3.2.2->-r requirements.txt (line 4))
#   Using cached pyparsing-3.1.0-py3-none-any.whl (102 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/aiml-3080/.local/lib/python3.7/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/aiml-3080/.local/lib/python3.7/site-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (2.0.12)
# Collecting idna<4,>=2.5 (from requests>=2.23.0->-r requirements.txt (line 9))
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.23.0->-r requirements.txt (line 9))
#   Using cached urllib3-2.0.3-py3-none-any.whl (123 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /home/aiml-3080/Downloads/MJ/miniconda3/envs/yolo/lib/python3.7/site-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (2023.5.7)
# Requirement already satisfied: typing-extensions in /home/aiml-3080/.local/lib/python3.7/site-packages (from torch>=1.7.0->-r requirements.txt (line 11)) (4.3.0)
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from torch>=1.7.0->-r requirements.txt (line 11))
#   Using cached nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from torch>=1.7.0->-r requirements.txt (line 11))
#   Using cached nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
# Collecting nvidia-cublas-cu11==11.10.3.66 (from torch>=1.7.0->-r requirements.txt (line 11))
#   Using cached nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from torch>=1.7.0->-r requirements.txt (line 11))
#   Using cached nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
# Requirement already satisfied: setuptools in /home/aiml-3080/.local/lib/python3.7/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.7.0->-r requirements.txt (line 11)) (68.0.0)
# Requirement already satisfied: wheel in /home/aiml-3080/.local/lib/python3.7/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.7.0->-r requirements.txt (line 11)) (0.37.1)
# Collecting absl-py>=0.4 (from tensorboard>=2.4.1->-r requirements.txt (line 16))
#   Using cached absl_py-1.4.0-py3-none-any.whl (126 kB)
# Requirement already satisfied: grpcio>=1.24.3 in /home/aiml-3080/.local/lib/python3.7/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (1.56.0)
# Collecting google-auth<3,>=1.6.3 (from tensorboard>=2.4.1->-r requirements.txt (line 16))
#   Downloading google_auth-2.21.0-py2.py3-none-any.whl (182 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.1/182.1 kB 975.5 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/aiml-3080/.local/lib/python3.7/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /home/aiml-3080/.local/lib/python3.7/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (3.3.7)
# Collecting protobuf<4,>=3.9.2 (from tensorboard>=2.4.1->-r requirements.txt (line 16))
#   Using cached protobuf-3.20.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/aiml-3080/.local/lib/python3.7/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/aiml-3080/.local/lib/python3.7/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/aiml-3080/.local/lib/python3.7/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (2.1.2)
# Collecting pytz>=2017.3 (from pandas>=1.1.4->-r requirements.txt (line 20))
#   Using cached pytz-2023.3-py2.py3-none-any.whl (502 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 16))
#   Using cached cachetools-5.3.1-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/aiml-3080/.local/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 16)) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/aiml-3080/.local/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 16)) (4.8)
# Requirement already satisfied: six>=1.9.0 in /home/aiml-3080/Downloads/MJ/miniconda3/envs/yolo/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 16)) (1.16.0)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.23.0->-r requirements.txt (line 9))
#   Using cached urllib3-1.26.16-py2.py3-none-any.whl (143 kB)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/aiml-3080/.local/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.4.1->-r requirements.txt (line 16)) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/aiml-3080/.local/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard>=2.4.1->-r requirements.txt (line 16)) (4.11.4)
# Requirement already satisfied: zipp>=0.5 in /home/aiml-3080/.local/lib/python3.7/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.4.1->-r requirements.txt (line 16)) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/aiml-3080/.local/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 16)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/aiml-3080/.local/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.4.1->-r requirements.txt (line 16)) (3.2.0)
# Installing collected packages: pytz, urllib3, tqdm, pyparsing, protobuf, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cublas-cu11, numpy, kiwisolver, idna, fonttools, cycler, cachetools, absl-py, scipy, requests, pandas, opencv-python, nvidia-cudnn-cu11, matplotlib, google-auth, torch, torchvision, thop, tensorboard
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.19.9
#     Uninstalling tqdm-4.19.9:
#       Successfully uninstalled tqdm-4.19.9
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.2.1
#     Uninstalling scipy-1.2.1:
#       Successfully uninstalled scipy-1.2.1
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.0.0.21
#     Uninstalling opencv-python-4.0.0.21:
#       Successfully uninstalled opencv-python-4.0.0.21
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.0.3
#     Uninstalling matplotlib-3.0.3:
#       Successfully uninstalled matplotlib-3.0.3
#   Attempting uninstall: torch
#     Found existing installation: torch 1.0.1.post2
#     Uninstalling torch-1.0.1.post2:
#       Successfully uninstalled torch-1.0.1.post2
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.2.2
#     Uninstalling torchvision-0.2.2:
#       Successfully uninstalled torchvision-0.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# imgaug 0.2.8 requires scikit-image>=0.11.0, which is not installed.
# scikit-learn 0.21.2 requires joblib>=0.11, which is not installed.
# tensorflow-gpu 1.15.4 requires astor>=0.6.0, which is not installed.
# tensorflow-gpu 1.15.4 requires gast==0.2.2, which is not installed.
# tensorflow-gpu 1.15.4 requires google-pasta>=0.1.6, which is not installed.
# tensorflow-gpu 1.15.4 requires keras-applications>=1.0.8, which is not installed.
# tensorflow-gpu 1.15.4 requires keras-preprocessing>=1.0.5, which is not installed.
# tensorflow-gpu 1.15.4 requires opt-einsum>=2.3.2, which is not installed.
# tensorflow-gpu 1.15.4 requires tensorflow-estimator==1.15.1, which is not installed.
# tensorflow-gpu 1.15.4 requires termcolor>=1.1.0, which is not installed.
# tensorflow-gpu 1.15.4 requires wrapt>=1.11.1, which is not installed.
# tensorflow-gpu 1.15.4 requires numpy<1.19.0,>=1.16.0, but you have numpy 1.21.6 which is incompatible.
# tensorflow-gpu 1.15.4 requires tensorboard<1.16.0,>=1.15.0, but you have tensorboard 2.11.2 which is incompatible.
# Successfully installed absl-py-1.4.0 cachetools-5.3.1 cycler-0.11.0 fonttools-4.38.0 google-auth-2.21.0 idna-3.4 kiwisolver-1.4.4 matplotlib-3.5.3 numpy-1.21.6 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 opencv-python-4.7.0.72 pandas-1.3.5 protobuf-3.20.3 pyparsing-3.1.0 pytz-2023.3 requests-2.31.0 scipy-1.7.3 tensorboard-2.11.2 thop-0.1.1.post2209072238 torch-1.13.1 torchvision-0.14.1 tqdm-4.65.0 urllib3-1.26.16

# %%
# %%bash
# conda install -c conda-forge cudatoolkit=11.2.*
# pip install nvidia-cudnn-cu11==8.2.*
# mkdir -p $CONDA_PREFIX/etc/conda/activate.d
# echo 'CUDNN_PATH=$(dirname $(python -c "import nvidia.cudnn;print(nvidia.cudnn.__file__)"))' >> $CONDA_PREFIX/etc/conda/activate.d/env_vars.sh
# echo 'export LD_LIBRARY_PATH=$LD_LIBRARY_PATH:$CONDA_PREFIX/lib/:$CUDNN_PATH/lib' >> $CONDA_PREFIX/etc/conda/activate.d/env_vars.sh
# pip install tensorflow==2.10.*
# Out:
# Process is terminated.

# %% [markdown]
# # Integrating DeepSORT

# %% [markdown]
# Referencing the detector code from `yolov5/detect.py` and adding DeepSORT code to it into a new file `detect_track.py`

# %%
# %%writefile detect_track_original.py
# YOLOv5 🚀 by Ultralytics, GPL-3.0 license
"""
Run inference on images, videos, directories, streams, etc.

Usage - sources:
    $ python path/to/detect.py --weights yolov5s.pt --source 0              # webcam
                                                             img.jpg        # image
                                                             vid.mp4        # video
                                                             path/          # directory
                                                             path/*.jpg     # glob
                                                             'https://youtu.be/Zgi9g1ksQHc'  # YouTube
                                                             'rtsp://example.com/media.mp4'  # RTSP, RTMP, HTTP stream
"""

import argparse
import os
import sys
from pathlib import Path

import torch
import torch.backends.cudnn as cudnn

FILE = Path(__file__).resolve()
ROOT = FILE.parents[0]  # YOLOv5 root directory
if str(ROOT) not in sys.path:
    sys.path.append(str(ROOT))  # add ROOT to PATH
ROOT = Path(os.path.relpath(ROOT, Path.cwd()))  # relative

# DeepSORT -> Importing DeepSORT.
from deep_sort.application_util import preprocessing
from deep_sort.deep_sort import nn_matching
from deep_sort.deep_sort.detection import Detection
from deep_sort.deep_sort.tracker import Tracker
from deep_sort.tools import generate_detections as gdet

#importing Yolov5 helppers
from models.common import DetectMultiBackend
from utils.dataloaders import IMG_FORMATS, VID_FORMATS, LoadImages, LoadStreams
from utils.general import (LOGGER, check_file, check_img_size, check_imshow, check_requirements, colorstr, cv2,
                           increment_path, non_max_suppression, print_args, scale_coords, strip_optimizer, xyxy2xywh)
from utils.plots import Annotator, colors, save_one_box
from utils.torch_utils import select_device, time_sync


@torch.no_grad()
def run(
        weights=ROOT / 'yolov5s.pt',  # model.pt path(s)
        source=ROOT / 'data/images',  # file/dir/URL/glob, 0 for webcam
        data=ROOT / 'data/coco128.yaml',  # dataset.yaml path
        imgsz=(640, 640),  # inference size (height, width)
        conf_thres=0.25,  # confidence threshold
        iou_thres=0.45,  # NMS IOU threshold
        max_det=1000,  # maximum detections per image
        device='',  # cuda device, i.e. 0 or 0,1,2,3 or cpu
        view_img=False,  # show results
        save_txt=False,  # save results to *.txt
        save_conf=False,  # save confidences in --save-txt labels
        save_crop=False,  # save cropped prediction boxes
        nosave=False,  # do not save images/videos
        classes=None,  # filter by class: --class 0, or --class 0 2 3
        agnostic_nms=False,  # class-agnostic NMS
        augment=False,  # augmented inference
        visualize=False,  # visualize features
        update=False,  # update all models
        project=ROOT / 'runs/detect',  # save results to project/name
        name='exp',  # save results to project/name
        exist_ok=False,  # existing project/name ok, do not increment
        line_thickness=3,  # bounding box thickness (pixels)
        hide_labels=False,  # hide labels
        hide_conf=False,  # hide confidences
        half=False,  # use FP16 half-precision inference
        dnn=False,  # use OpenCV DNN for ONNX inference
        max_iou_distance=0.7, # max distance for tracker
        max_age=30, # max decay age in frames
        n_init=3 # first frames to be contiously detected in to be given a id
):
    
    # Check Source
    source = str(source)
    save_img = not nosave and not source.endswith('.txt')  # save inference images
    is_file = Path(source).suffix[1:] in (IMG_FORMATS + VID_FORMATS)
    is_url = source.lower().startswith(('rtsp://', 'rtmp://', 'http://', 'https://'))
    webcam = source.isnumeric() or source.endswith('.txt') or (is_url and not is_file)
    if is_url and is_file:
        source = check_file(source)  # download

    # DeepSORT -> Intializing tracker and encoder.
    max_cosine_distance = 0.4
    nn_budget = None
    model_filename = './model_data/mars-small128.pb' #using mars-model small 128d version
    encoder = gdet.create_box_encoder(model_filename, batch_size=1) #gives func encoder (INT8) gives image detected patches
    metric = nn_matching.NearestNeighborDistanceMetric("cosine", max_cosine_distance, nn_budget)
    tracker = Tracker(metric,max_iou_distance=max_iou_distance, max_age=max_age, n_init=n_init) #n_init = 3, max_age = 30 , dist = 0.7, kalman filter
    
    # Directories
    if not os.path.isdir('./runsmj/'):
      os.mkdir('./runsmj/')
    save_dir = os.path.join(os.getcwd(), "runsmj")
    print(save_dir)
    '''save_dir = increment_path(Path(project) / name, exist_ok=exist_ok)  # increment run
    (save_dir / 'labels' if save_txt else save_dir).mkdir(parents=True, exist_ok=True)  # make dir'''

    # Load model -> YOLOv5
    device = select_device(device) #class names from COCO128
    model = DetectMultiBackend(weights, device=device, dnn=dnn, data=data, fp16=half) #w=yolov5s.pt dnn=opencv half = false - fp16
    stride, names, pt = model.stride, model.names, model.pt
    imgsz = check_img_size(imgsz, s=stride)  # check image size

    # Dataloader
    if webcam:
        view_img = check_imshow()
        cudnn.benchmark = True  # set True to speed up constant image size inference
        dataset = LoadStreams(source, img_size=imgsz, stride=stride, auto=pt)
        bs = len(dataset)  # batch_size
    else:
        dataset = LoadImages(source, img_size=imgsz, stride=stride, auto=pt)
        bs = 1  # batch_size
    vid_path, vid_writer = [None] * bs, [None] * bs

    # Run inference by yolov5
    model.warmup(imgsz=(1 if pt else bs, 3, *imgsz))  # warmup
    dt, seen = [0.0, 0.0, 0.0], 0
    frame_idx=0
    # whats happening here 
    for path, im, im0s, vid_cap, s in dataset: # im - padded image, im0 - original detected image
        t1 =  time_sync()
        im = torch.from_numpy(im).to(device)
        im = im.half() if model.fp16 else im.float()  # uint8 to fp16/32
        im /= 255  # 0 - 255 to 0.0 - 1.0
        if len(im.shape) == 3:
            im = im[None]  # expand for batch dim
        t2 = time_sync()
        dt[0] += t2 - t1

        # Inference
        visualize = increment_path(save_dir / Path(path).stem, mkdir=True) if visualize else False
        pred = model(im, augment=augment, visualize=visualize)
        t3 = time_sync()
        dt[1] += t3 - t2

        # NMS
        pred = non_max_suppression(pred, conf_thres, iou_thres, classes, agnostic_nms, max_det=max_det)
        dt[2] += time_sync() - t3

        # Second-stage classifier (optional)
        # pred = utils.general.apply_classifier(pred, classifier_model, im, im0s)

        frame_idx=frame_idx+1
        # Process predictions
        for i, det in enumerate(pred):  # per image
            seen += 1
            if webcam:  # batch_size >= 1
                p, im0, frame = path[i], im0s[i].copy(), dataset.count
                s += f'{i}: '
            else:
                p, im0, frame = path, im0s.copy(), getattr(dataset, 'frame', 0)

            p = Path(p)  # to Path
            print("stem", p.stem)
            print("dir", save_dir)
            save_path = os.path.join(save_dir, p.name)  # im.jpg
            txt_path = os.path.join(save_dir , p.stem) # im.txt
            s += '%gx%g ' % im.shape[2:]  # print string
            gn = torch.tensor(im0.shape)[[1, 0, 1, 0]]  # normalization gain whwh
            imc = im0.copy() if save_crop else im0  # for save_crop
            annotator = Annotator(im0, line_width=line_thickness, example=str(names)) #init annotator for putting text on frame

            if len(det):
                # Rescale boxes from img_size to im0 size
                det[:, :4] = scale_coords(im.shape[2:], det[:, :4], im0.shape).round()

                # Print results of detetions to file 
                for c in det[:, -1].unique():
                    n = (det[:, -1] == c).sum()  # detections per class
                    s += f"{n} {names[int(c)]}{'s' * (n > 1)}, "  # add to string

                # DeepSORT -> Extracting Bounding boxes and its confidence scores.
                bboxes = []
                scores = []
                for *boxes, conf, cls in det:
                  bbox_left = min([boxes[0].item(), boxes[2].item()])
                  bbox_top = min([boxes[1].item(), boxes[3].item()])
                  bbox_w = abs(boxes[0].item() - boxes[2].item())
                  bbox_h = abs(boxes[1].item() - boxes[3].item())
                  box = [bbox_left, bbox_top, bbox_w, bbox_h]
                  bboxes.append(box)
                  scores.append(conf.item())
                
                # DeepSORT -> Getting appearence features of the object.
                features = encoder(im0, bboxes) #initialized in Tracker
                # DeepSORT -> Storing all the required info in a list.
                # Creating Detection object of all detections in 
                detections = [Detection(bbox, score, feature) for bbox, score, feature in zip(bboxes, scores, features)]

                # DeepSORT -> Predicting Tracks. 
                tracker.predict()
                tracker.update(detections)
                #track_time = time.time() - prev_time

                # DeepSORT -> Plotting the tracks.
                for track in tracker.tracks:
                  if not track.is_confirmed() or track.time_since_update > 1:
                      continue

                  # DeepSORT -> Changing track bbox to top left, bottom right coordinates
                  bbox = list(track.to_tlbr())

                  # DeepSORT -> Writing Track bounding box and ID on the frame using OpenCV.
                  txt = 'id:' + str(track.track_id)
                  (label_width,label_height), baseline = cv2.getTextSize(txt , cv2.FONT_HERSHEY_SIMPLEX,1,1)
                  top_left = tuple(map(int,[int(bbox[0]),int(bbox[1])-(label_height+baseline)]))
                  top_right = tuple(map(int,[int(bbox[0])+label_width,int(bbox[1])]))
                  org = tuple(map(int,[int(bbox[0]),int(bbox[1])-baseline]))

                  cv2.rectangle(im0, (int(bbox[0]), int(bbox[1])), (int(bbox[2]), int(bbox[3])), (255,0,0), 1)
                  cv2.rectangle(im0, top_left, top_right, (255,0,0), -1)
                  cv2.putText(im0, txt, org, cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 1)

                  # DeepSORT -> Saving Track predictions into a text file.
                  save_format = '{frame},{id},{x1},{y1},{w},{h},{x},{y},{z}\n'
                  print("txt: ", txt_path, '.txt')
                  with open(txt_path + '.txt', 'a') as f:
                    line = save_format.format(frame=frame_idx, id=track.track_id, x1=int(bbox[0]), y1=int(bbox[1]), w=int(bbox[2]- bbox[0]), h=int(bbox[3]-bbox[1]), x = -1, y = -1, z = -1)
                    f.write(line) 

            # Stream results
            im0 = annotator.result()

            # Save results (image with detections and tracks)
            if save_img:
                if dataset.mode == 'image':
                    cv2.imwrite(save_path, im0)
                else:  # 'video' or 'stream'
                    if vid_path[i] != save_path:  # new video
                        vid_path[i] = save_path
                        if isinstance(vid_writer[i], cv2.VideoWriter):
                            vid_writer[i].release()  # release previous video writer
                        if vid_cap:  # video
                            fps = vid_cap.get(cv2.CAP_PROP_FPS)
                            w = int(vid_cap.get(cv2.CAP_PROP_FRAME_WIDTH))
                            h = int(vid_cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
                        else:  # stream
                            fps, w, h = 30, im0.shape[1], im0.shape[0]
                        save_path = str(Path(save_path).with_suffix('.mp4'))  # force *.mp4 suffix on results videos
                        vid_writer[i] = cv2.VideoWriter(save_path, cv2.VideoWriter_fourcc(*'mp4v'), fps, (w, h))
                    vid_writer[i].write(im0)

        # Print time (inference-only)
        LOGGER.info(f'{s}Done. ({t3 - t2:.3f}s)')

    # Print results
    t = tuple(x / seen * 1E3 for x in dt)  # speeds per image
    LOGGER.info(f'Speed: %.1fms pre-process, %.1fms inference, %.1fms NMS per image at shape {(1, 3, *imgsz)}' % t)
    if update:
        strip_optimizer(weights)  # update model (to fix SourceChangeWarning)


def parse_opt():
    parser = argparse.ArgumentParser()
    parser.add_argument('--weights', nargs='+', type=str, default=ROOT / 'yolov5s.pt', help='model path(s)')
    parser.add_argument('--source', type=str, default=ROOT / 'data/images', help='file/dir/URL/glob, 0 for webcam')
    parser.add_argument('--data', type=str, default=ROOT / 'data/coco128.yaml', help='(optional) dataset.yaml path')
    parser.add_argument('--imgsz', '--img', '--img-size', nargs='+', type=int, default=[640], help='inference size h,w')
    parser.add_argument('--conf-thres', type=float, default=0.25, help='confidence threshold')
    parser.add_argument('--iou-thres', type=float, default=0.45, help='NMS IoU threshold')
    parser.add_argument('--max-det', type=int, default=1000, help='maximum detections per image')
    parser.add_argument('--device', default='', help='cuda device, i.e. 0 or 0,1,2,3 or cpu')
    parser.add_argument('--view-img', action='store_true', help='show results')
    parser.add_argument('--save-txt', action='store_true', help='save results to *.txt')
    parser.add_argument('--save-conf', action='store_true', help='save confidences in --save-txt labels')
    parser.add_argument('--save-crop', action='store_true', help='save cropped prediction boxes')
    parser.add_argument('--nosave', action='store_true', help='do not save images/videos')
    parser.add_argument('--classes', nargs='+', type=int, help='filter by class: --classes 0, or --classes 0 2 3')
    parser.add_argument('--agnostic-nms', action='store_true', help='class-agnostic NMS')
    parser.add_argument('--augment', action='store_true', help='augmented inference')
    parser.add_argument('--visualize', action='store_true', help='visualize features')
    parser.add_argument('--update', action='store_true', help='update all models')
    parser.add_argument('--project', default=ROOT / 'runs/detect', help='save results to project/name')
    parser.add_argument('--name', default='exp', help='save results to project/name')
    parser.add_argument('--exist-ok', action='store_true', help='existing project/name ok, do not increment')
    parser.add_argument('--line-thickness', default=3, type=int, help='bounding box thickness (pixels)')
    parser.add_argument('--hide-labels', default=False, action='store_true', help='hide labels')
    parser.add_argument('--hide-conf', default=False, action='store_true', help='hide confidences')
    parser.add_argument('--half', action='store_true', help='use FP16 half-precision inference')
    parser.add_argument('--dnn', action='store_true', help='use OpenCV DNN for ONNX inference')
    opt = parser.parse_args()
    opt.imgsz *= 2 if len(opt.imgsz) == 1 else 1  # expand
    print_args(vars(opt))
    return opt

def main(opt):
    check_requirements(exclude=('tensorboard', 'thop'))
    run(**vars(opt))

if __name__ == "__main__":
    opt = parse_opt()
    main(opt)
# Out:
# Writing detect_track_original.py

# %% [markdown]
# # Inference

# %% [markdown]
# Running DeepSORT on sports video.
#
#
# *   [Football video](https://drive.google.com/file/d/1RHjI-dtvrqGgnhIstB2d2ol-nTHvNUiE/view?usp=sharing)
# *   [Sprint race](https://drive.google.com/file/d/13z3Nbqc77lByNPU6gHJ_fOIxxFCUtC7J/view?usp=sharing)

# %%
# !python detect_track.py --weights yolov5l.pt  --img 640  --source ./football-video.mp4 --classes 0 32 --line-thickness 1 --project MJ
# Out:
# 2023-06-22 16:03:51.004858: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-22 16:03:51.515163: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/aiml-3080/.local/lib/python3.7/site-packages/cv2/../../lib64::/usr/local/cuda/lib64:/usr/local/cuda-11/lib64:/usr/local/cuda-11.4/lib64:/home/aiml-3080/Downloads/MJ/.conda/lib/:/home/aiml-3080/Downloads/MJ/.conda/lib/python3.7/site-packages/nvidia/cudnn/lib
# 2023-06-22 16:03:51.515224: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/aiml-3080/.local/lib/python3.7/site-packages/cv2/../../lib64::/usr/local/cuda/lib64:/usr/local/cuda-11/lib64:/usr/local/cuda-11.4/lib64:/home/aiml-3080/Downloads/MJ/.conda/lib/:/home/aiml-3080/Downloads/MJ/.conda/lib/python3.7/site-packages/nvidia/cudnn/lib
# 2023-06-22 16:03:51.515233: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# WARNING:tensorflow:From /home/aiml-3080/Downloads/MJ/.conda/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# detect_track: weights=['yolov5l.pt'], source=./football-video.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=[0, 32], agnostic_nms=False, augment=False, visualize=False, update=False, project=MJ, name=exp, exist_ok=False, line_thickness=1, hide_labels=False, hide_conf=False, half=False, dnn=False
# 2023-06-22 16:03:52.786439: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-22 16:03:52.789401: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-22 16:03:52.789774: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-22 16:03:52.790406: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-22 16:03:52.791048: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-22 16:03:52.791431: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-22 16:03:52.791695: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-22 16:03:54.413059: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-22 16:03:54.413334: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-22 16:03:54.413568: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-22 16:03:54.413799: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7088 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:03:00.0, compute capability: 8.6
# /home/aiml-3080/Downloads/MJ/yolov5/runs
# YOLOv5 🚀 2022-7-7 Python-3.7.12 torch-1.13.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3080, 10010MiB)
#
# Fusing layers...
# YOLOv5l summary: 367 layers, 46533693 parameters, 0 gradients
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# 2023-06-22 16:03:56.842291: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:357] MLIR V1 optimization pass is not enabled
# 2023-06-22 16:03:57.025813: I tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:735] failed to allocate 6.92G (7432896512 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2023-06-22 16:03:57.082478: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8202
# 2023-06-22 16:03:57.167466: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# video 1/1 (1/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 7 persons, Done. (0.015s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# video 1/1 (2/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 6 persons, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (3/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 6 persons, 1 sports ball, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (4/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 6 persons, 1 sports ball, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (5/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 5 persons, Done. (0.013s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (6/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 5 persons, Done. (0.013s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (7/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 5 persons, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (8/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 5 persons, Done. (0.011s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (9/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 5 persons, 1 sports ball, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (10/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 5 persons, 1 sports ball, Done. (0.012s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (11/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 5 persons, 1 sports ball, Done. (0.011s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (12/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 3 persons, 1 sports ball, Done. (0.011s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (13/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 4 persons, 1 sports ball, Done. (0.012s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (14/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 4 persons, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (15/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 4 persons, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (16/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 3 persons, Done. (0.011s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (17/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 3 persons, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (18/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 3 persons, Done. (0.009s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (19/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 3 persons, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (20/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 4 persons, Done. (0.009s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (21/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 4 persons, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (22/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 4 persons, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (23/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 5 persons, Done. (0.009s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (24/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 5 persons, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (25/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 5 persons, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (26/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 6 persons, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (27/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 4 persons, Done. (0.011s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (28/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 4 persons, Done. (0.011s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (29/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 4 persons, Done. (0.011s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (30/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 5 persons, Done. (0.009s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (31/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 5 persons, Done. (0.009s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (32/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 5 persons, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (33/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 4 persons, 1 sports ball, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (34/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 4 persons, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (35/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 4 persons, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (36/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 4 persons, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (37/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 4 persons, Done. (0.011s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (38/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 4 persons, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (39/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 4 persons, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (40/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 4 persons, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (41/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 4 persons, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (42/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 5 persons, Done. (0.009s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (43/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 4 persons, Done. (0.009s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (44/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 4 persons, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (45/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 4 persons, Done. (0.009s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (46/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 3 persons, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (47/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 3 persons, 1 sports ball, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (48/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 3 persons, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (49/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 4 persons, Done. (0.009s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (50/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 3 persons, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (51/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 3 persons, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (52/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 3 persons, Done. (0.012s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (53/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 3 persons, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (54/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 3 persons, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (55/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 3 persons, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (56/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 3 persons, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (57/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.009s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# video 1/1 (58/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (59/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.009s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (60/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (61/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.009s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (62/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.009s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (63/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (64/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.009s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (65/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.009s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (66/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (67/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (68/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.009s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (69/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.012s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (70/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.009s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (71/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (72/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (73/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.011s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (74/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (75/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.009s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (76/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.009s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (77/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.009s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (78/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (79/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (80/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (81/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.009s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (82/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (83/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.009s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (84/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (85/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.012s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (86/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (87/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.009s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (88/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (89/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (90/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (91/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (92/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (93/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.009s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (94/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (95/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.011s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (96/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.009s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (97/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (98/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (99/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.009s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (100/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (101/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (102/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (103/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.011s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (104/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.009s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (105/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.009s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (106/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (107/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (108/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (109/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.013s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (110/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.013s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (111/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.012s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (112/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (113/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.012s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (114/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (115/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.011s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (116/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (117/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (118/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (119/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (120/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (121/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 1 person, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (122/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 6 persons, 1 sports ball, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# video 1/1 (123/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 5 persons, 1 sports ball, Done. (0.011s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (124/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 6 persons, 1 sports ball, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (125/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 5 persons, 1 sports ball, Done. (0.009s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# ...
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (1046/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 5 persons, Done. (0.011s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (1047/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 4 persons, Done. (0.014s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (1048/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 4 persons, Done. (0.014s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (1049/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 5 persons, Done. (0.012s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (1050/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 5 persons, Done. (0.011s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (1051/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 6 persons, Done. (0.011s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (1052/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 7 persons, Done. (0.011s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (1053/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 6 persons, Done. (0.012s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (1054/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 6 persons, Done. (0.014s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (1055/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 8 persons, Done. (0.011s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (1056/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 6 persons, Done. (0.014s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (1057/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 5 persons, Done. (0.013s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (1058/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 5 persons, Done. (0.012s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (1059/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 5 persons, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (1060/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 5 persons, Done. (0.011s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (1061/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 5 persons, Done. (0.011s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (1062/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 5 persons, Done. (0.011s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (1063/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 5 persons, Done. (0.011s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (1064/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 6 persons, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (1065/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 6 persons, Done. (0.014s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (1066/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 4 persons, Done. (0.015s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (1067/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 4 persons, Done. (0.013s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (1068/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 4 persons, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (1069/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 5 persons, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (1070/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 5 persons, Done. (0.010s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (1071/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 6 persons, Done. (0.011s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (1072/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 6 persons, Done. (0.015s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (1073/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 5 persons, Done. (0.014s)
# stem football-video
# dir /home/aiml-3080/Downloads/MJ/yolov5/runs
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# txt:  /home/aiml-3080/Downloads/MJ/yolov5/runs/football-video .txt
# video 1/1 (1074/1074) /home/aiml-3080/Downloads/MJ/yolov5/football-video.mp4: 384x640 2 persons, Done. (0.013s)
# Speed: 0.6ms pre-process, 13.3ms inference, 1.2ms NMS per image at shape (1, 3, 640, 640)

# %%
# !python detect_track_original.py --weights yolov5m.pt  --img 640  --source imagetest.png --save-txt --classes 0 --line-thickness 1
# Out:
# WARNING:tensorflow:From /home/aiml-3080/.local/lib/python3.7/site-packages/tensorflow_core/python/compat/v2_compat.py:68: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# detect_track_original: weights=['yolov5m.pt'], source=imagetest.png, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=[0], agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=1, hide_labels=False, hide_conf=False, half=False, dnn=False
# 2023-06-27 15:16:50.849471: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2023-06-27 15:16:50.897768: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-27 15:16:50.898059: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: NVIDIA GeForce RTX 3080 major: 8 minor: 6 memoryClockRate(GHz): 1.71
# pciBusID: 0000:03:00.0
# 2023-06-27 15:16:50.898233: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-06-27 15:16:50.898926: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-06-27 15:16:50.899664: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2023-06-27 15:16:50.899844: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2023-06-27 15:16:50.900740: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2023-06-27 15:16:50.901414: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2023-06-27 15:16:50.903517: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-06-27 15:16:50.903682: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-27 15:16:50.905481: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-27 15:16:50.905953: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2023-06-27 15:16:50.906216: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2023-06-27 15:16:50.911348: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 3699850000 Hz
# 2023-06-27 15:16:50.911875: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5650fd719660 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-06-27 15:16:50.911906: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-06-27 15:16:50.982478: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-27 15:16:50.982906: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5650fd700c30 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-06-27 15:16:50.982923: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3080, Compute Capability 8.6
# 2023-06-27 15:16:50.983128: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-27 15:16:50.983523: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: NVIDIA GeForce RTX 3080 major: 8 minor: 6 memoryClockRate(GHz): 1.71
# pciBusID: 0000:03:00.0
# 2023-06-27 15:16:50.983614: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-06-27 15:16:50.983643: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2023-06-27 15:16:50.983661: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2023-06-27 15:16:50.983680: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2023-06-27 15:16:50.983698: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2023-06-27 15:16:50.983716: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2023-06-27 15:16:50.983735: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2023-06-27 15:16:50.983797: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-27 15:16:50.985190: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-27 15:16:50.986042: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2023-06-27 15:16:50.986126: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2023-06-27 15:16:50.987188: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-06-27 15:16:50.987202: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2023-06-27 15:16:50.987207: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2023-06-27 15:16:50.987317: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-27 15:16:50.987689: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-27 15:16:50.987981: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 8769 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:03:00.0, compute capability: 8.6)
# /home/aiml-3080/Downloads/MJ/yolo/yolov5/runsmj
# YOLOv5 🚀 2023-6-26 Python-3.7.12 torch-1.13.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3080, 10010MiB)
#
# Fusing layers...
# YOLOv5m summary: 290 layers, 21172173 parameters, 0 gradients
# stem imagetest
# dir /home/aiml-3080/Downloads/MJ/yolo/yolov5/runsmj
# encoderin
# encoderout
# 2023-06-27 15:16:54.659220: I tensorflow/stream_executor/cuda/cuda_driver.cc:831] failed to allocate 8.56G (9195808256 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2023-06-27 15:16:54.659950: I tensorflow/stream_executor/cuda/cuda_driver.cc:831] failed to allocate 7.71G (8276227584 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# ^C

# %%
# !python detect_track.py --weights yolov5m.pt  --img 640  --source imagetest.png --save-txt --classes 0 --line-thickness 1
# Out:
# Traceback (most recent call last):
#   File "/home/aiml-3080/Downloads/MJ/yolo/yolov5/detect_track.py", line 34, in <module>
#     from deep_sort.tools import generate_detections as gdet
#   File "/home/aiml-3080/Downloads/MJ/yolo/yolov5/deep_sort/tools/generate_detections.py", line 7, in <module>
#     import tensorflow.compat.v1 as tf
# ModuleNotFoundError: No module named 'tensorflow'

# %% [markdown]
# # Performance evaluation

# %% [markdown]
# ## Running DeepSORT on MOT17 videos.

# %% [markdown]
# Download MOT videos and labels from [here](https://drive.google.com/drive/folders/1MUa8H9kaW3gTkvn4BYd-84mqlfgC-kE4?usp=sharing).

# %%
# !python detect_track.py --weights yolov5m.pt  --img 640  --source ./MOT17/videos/MOT17-02-DPM.mp4 --save-txt --class 0 --line-thickness 1

# %%
# !python detect_track.py --weights yolov5m.pt  --img 640  --source ./MOT17/videos/MOT17-04-DPM.mp4 --save-txt --class 0 --line-thickness 1

# %%
# !python detect_track.py --weights yolov5m.pt  --img 640  --source ./MOT17/videos/MOT17-10-DPM.mp4 --save-txt --class 0 --line-thickness 1

# %% [markdown]
# ## Cloning MOT evaluation code

# %%
# !git clone https://github.com/shenh10/mot_evaluation.git

# %%
# %cd ./mot_evaluation

# %% [markdown]
# ## Performing evaluation

# %%
# !python evaluate_tracking.py --seqmap '../MOT17/videos' --track '../runs/' --gt '/content/gdrive/MyDrive/tracking_test_data/person_gt_tracking/label_960x540'
# Out:
# [GT PREPROCESSING]: Removing non-people classes, remaining 52355/108005 boxes
# [TRACK PREPROCESSING]: remove distractors and low visibility boxes,remaining 22685/22892 computed boxes
# Distractors: 45, 46, 79, 81, 136
# [GT PREPROCESSING]: Removing distractor boxes, remaining 47557/52355 boxes
#
# ****************************** MOT17-04-DPM.mp4 Evaluation ******************************
# IDF1  IDP  IDR  | Rcll  Prcn  FAR   | GT   MT   PT   ML   | FP     FN     IDs   FM    | MOTA  MOTP  MOTAL
#  47.2 73.1 34.9 |  36.5  82.4  3.54 |   83    6   38   39 |   3720  30195    45   239 |  28.6  82.2  28.7
#
#
#
# [GT PREPROCESSING]: Removing non-people classes, remaining 26601/30003 boxes
# [TRACK PREPROCESSING]: remove distractors and low visibility boxes,remaining 7313/7865 computed boxes
# Distractors: 1, 5, 6, 11, 12, 13, 24, 25, 30, 45, 46, 47, 65, 66
# [GT PREPROCESSING]: Removing distractor boxes, remaining 18581/26601 boxes
#
# ****************************** MOT17-02-DPM.mp4 Evaluation ******************************
# IDF1  IDP  IDR  | Rcll  Prcn  FAR   | GT   MT   PT   ML   | FP     FN     IDs   FM    | MOTA  MOTP  MOTAL
#  31.5 55.8 22.0 |  30.6  77.9  2.70 |   62    7   19   36 |   1619  12887    87   187 |  21.5  77.9  21.9
#
#
#
# [GT PREPROCESSING]: Removing non-people classes, remaining 14685/17450 boxes
# [TRACK PREPROCESSING]: remove distractors and low visibility boxes,remaining 7776/8334 computed boxes
# Distractors: 51, 52, 61, 62, 63, 64
# [GT PREPROCESSING]: Removing distractor boxes, remaining 12839/14685 boxes
#
# ****************************** MOT17-10-DPM.mp4 Evaluation ******************************
# IDF1  IDP  IDR  | Rcll  Prcn  FAR   | GT   MT   PT   ML   | FP     FN     IDs   FM    | MOTA  MOTP  MOTAL
#  42.9 56.9 34.5 |  50.2  82.9  2.03 |   57   11   24   22 |   1329   6392   104   276 |  39.1  74.7  39.8
#
#
#
#
# ****************************** Summary Evaluation ******************************
# IDF1  IDP  IDR  | Rcll  Prcn  FAR   | GT   MT   PT   ML   | FP     FN     IDs   FM    | MOTA  MOTP  MOTAL
#  43.0 66.4 31.8 |  37.4  81.6  2.89 |  202   24   81   97 |   6668  49474   236   702 |  28.6  79.7  28.9
